# %%
import pandas as pd

# %%
l = [12,9,5]
s1 = pd.Series(l)

print(s1)
# Out:
# 0    12
# 1     9
# 2     5
# dtype: int64

# %%
l = [12,9,5]
s1 = pd.Series(l, index=["a","b","c"])

print(s1)
# Out:
# a    12
# b     9
# c     5
# dtype: int64

# %%
df = pd.read_csv("E:\\#Projects\\DataScience&Analisys\\Resources\\Pandas Resources\\Pandas Resources\\Black_friday_sale.csv", header = 0)

df.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
df = pd.read_csv("E:\\#Projects\\DataScience&Analisys\\Resources\\Pandas Resources\\Pandas Resources\\Black_friday_sale.csv",index_col=0, header = 0)

df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       161255.000000
# mean        8.085407        0.410070            5.276542            9.849586
# std         6.521146        0.491847            3.736380            5.094943
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            5.000000
# 50%         7.000000        0.000000            5.000000            9.000000
# 75%        14.000000        1.000000            8.000000           15.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count        71037.000000
# mean            12.669454
# std              4.125944
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233599 entries, 1000004 to 1006039
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  233599 non-null  object
#  1   Gender                      233599 non-null  object
#  2   Age                         233599 non-null  object
#  3   Occupation                  233599 non-null  int64
#  4   City_Category               233599 non-null  object
#  5   Stay_In_Current_City_Years  233599 non-null  object
#  6   Marital_Status              233599 non-null  int64
#  7   Product_Category_1          233599 non-null  int64
#  8   Product_Category_2          161255 non-null  float64
#  9   Product_Category_3          71037 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 19.6+ MB

# %%
# Empty values
df.tail()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1006036  P00118942      F  26-35          15             B
# 1006036  P00254642      F  26-35          15             B
# 1006036  P00031842      F  26-35          15             B
# 1006037  P00124742      F  46-50           1             C
# 1006039  P00316642      F  46-50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1006036                         4+               1                   8
# 1006036                         4+               1                   5
# 1006036                         4+               1                   1
# 1006037                         4+               0                  10
# 1006039                         4+               1                   4
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1006036                 NaN                 NaN
# 1006036                 8.0                 NaN
# ...

# %%
new_df = df.dropna()
new_df
df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       161255.000000
# mean        8.085407        0.410070            5.276542            9.849586
# std         6.521146        0.491847            3.736380            5.094943
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            5.000000
# 50%         7.000000        0.000000            5.000000            9.000000
# 75%        14.000000        1.000000            8.000000           15.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count        71037.000000
# mean            12.669454
# std              4.125944
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %%
new_df = df.fillna(0)
new_df
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
# ...            ...    ...    ...         ...           ...
# 1006036  P00118942      F  26-35          15             B
# 1006036  P00254642      F  26-35          15             B
# 1006036  P00031842      F  26-35          15             B
# 1006037  P00124742      F  46-50           1             C
# 1006039  P00316642      F  46-50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# ...

# %%
new_df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       233599.000000
# mean        8.085407        0.410070            5.276542            6.799237
# std         6.521146        0.491847            3.736380            6.217668
# min         0.000000        0.000000            1.000000            0.000000
# 25%         2.000000        0.000000            1.000000            0.000000
# 50%         7.000000        0.000000            5.000000            5.000000
# 75%        14.000000        1.000000            8.000000           14.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count       233599.000000
# mean             3.852756
# std              6.256634
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              8.000000
# max             18.000000

# %%
mean = df['Product_Category_3'].mean()
new_df = df.fillna(mean)
new_df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       233599.000000
# mean        8.085407        0.410070            5.276542           10.722880
# std         6.521146        0.491847            3.736380            4.429356
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            8.000000
# 50%         7.000000        0.000000            5.000000           12.669454
# 75%        14.000000        1.000000            8.000000           14.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count       233599.000000
# mean            12.669454
# std              2.275244
# min              3.000000
# 25%             12.669454
# 50%             12.669454
# 75%             12.669454
# max             18.000000

# %%
median = df['Product_Category_3'].median()
new_df = df.fillna(median)
new_df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       233599.000000
# mean        8.085407        0.410070            5.276542           11.134941
# std         6.521146        0.491847            3.736380            4.647783
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            8.000000
# 50%         7.000000        0.000000            5.000000           14.000000
# 75%        14.000000        1.000000            8.000000           14.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count       233599.000000
# mean            13.595384
# std              2.356138
# min              3.000000
# 25%             14.000000
# 50%             14.000000
# 75%             14.000000
# max             18.000000

# %%
mode = df['Product_Category_3'].mode(dropna=False)
new_df = df.fillna(mode)
new_df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       161255.000000
# mean        8.085407        0.410070            5.276542            9.849586
# std         6.521146        0.491847            3.736380            5.094943
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            5.000000
# 50%         7.000000        0.000000            5.000000            9.000000
# 75%        14.000000        1.000000            8.000000           15.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count        71037.000000
# mean            12.669454
# std              4.125944
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %%
import numpy as np

# %%
df["Product_Category_1"].replace(np.nan, 0, inplace = True)
df["Product_Category_2"].replace(np.nan, 0, inplace = True)
df["Product_Category_3"].replace(np.nan, 0, inplace = True)
df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# 1000010                         4+               1                   5
# 1000010                         4+               1                   4
# 1000011                          1               0                   4
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 0.0
# 1000009                 5.0                 0.0
# ...

# %%
df["Stay_In_Current_City_Years"].replace('4+', 4, inplace = True)

uniques = df["Age"].unique()
max_ages = list(map(lambda i: i[-2:] if i[-1:] != "+" else '60', uniques))

df["Age"].replace(uniques, max_ages, inplace = True)

df
# Out:
#         Product_ID Gender Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  50           7             B
# 1000009  P00113442      M  35          17             C
# 1000010  P00288442      F  45           1             B
# 1000010  P00145342      F  45           1             B
# 1000011  P00053842      F  35           1             C
# ...            ...    ...  ..         ...           ...
# 1006036  P00118942      F  35          15             B
# 1006036  P00254642      F  35          15             B
# 1006036  P00031842      F  35          15             B
# 1006037  P00124742      F  50           1             C
# 1006039  P00316642      F  50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# ...

# %%
df.describe()

df['Age'] = pd.to_numeric(df["Age"])
df['Stay_In_Current_City_Years'] = pd.to_numeric(df['Stay_In_Current_City_Years'])

print(df.dtypes)
df.describe()
# Out:
# Product_ID                     object
# Gender                         object
# Age                             int64
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object
#                  Age     Occupation  Stay_In_Current_City_Years  \
# count  233599.000000  233599.000000               233599.000000
# mean       38.331324       8.085407                    1.857846
# std        10.327941       6.521146                    1.287256
# min        17.000000       0.000000                    0.000000
# 25%        35.000000       2.000000                    1.000000
# 50%        35.000000       7.000000                    2.000000
# 75%        45.000000      14.000000                    3.000000
# ...

# %%
df_wo_duplicates = df.drop_duplicates(subset=['Gender'], keep='first', inplace=False, ignore_index=True)
df_wo_duplicates
# Out:
#   Product_ID Gender  Age  Occupation City_Category  \
# 0  P00128942      M   50           7             B
# 1  P00288442      F   45           1             B
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               1                   1
# 1                           4               1                   5
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 0.0
# 1                14.0                 0.0

# %%
df
# Out:
#         Product_ID Gender  Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M   50           7             B
# 1000009  P00113442      M   35          17             C
# 1000010  P00288442      F   45           1             B
# 1000010  P00145342      F   45           1             B
# 1000011  P00053842      F   35           1             C
# ...            ...    ...  ...         ...           ...
# 1006036  P00118942      F   35          15             B
# 1006036  P00254642      F   35          15             B
# 1006036  P00031842      F   35          15             B
# 1006037  P00124742      F   50           1             C
# 1006039  P00316642      F   50           0             B
#
#          Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                           2               1                   1
# 1000009                           0               0                   3
# ...

# %%
df.corr()
# Out:
# C:\Users\Sivko\AppData\Local\Temp\ipykernel_31364\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                  Age  Occupation  Stay_In_Current_City_Years  \
# Age                         1.000000    0.095893                   -0.002410
# Occupation                  0.095893    1.000000                    0.024911
# Stay_In_Current_City_Years -0.002410    0.024911                    1.000000
# Marital_Status              0.305679    0.021872                   -0.012994
# Product_Category_1          0.058256   -0.010465                   -0.001808
# Product_Category_2          0.025351    0.009089                    0.004142
# Product_Category_3         -0.007014    0.013456                   -0.000681
#
# ...

# %% [markdown]
# **Oh, My God)**
# PostgreSql
#
# Let's start

# %%
df
# Out:
#         Product_ID Gender  Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M   50           7             B
# 1000009  P00113442      M   35          17             C
# 1000010  P00288442      F   45           1             B
# 1000010  P00145342      F   45           1             B
# 1000011  P00053842      F   35           1             C
# ...            ...    ...  ...         ...           ...
# 1006036  P00118942      F   35          15             B
# 1006036  P00254642      F   35          15             B
# 1006036  P00031842      F   35          15             B
# 1006037  P00124742      F   50           1             C
# 1006039  P00316642      F   50           0             B
#
#          Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                           2               1                   1
# 1000009                           0               0                   3
# ...
